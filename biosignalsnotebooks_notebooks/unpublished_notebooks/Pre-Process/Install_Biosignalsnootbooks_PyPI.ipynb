# %% [markdown]
# <link rel="stylesheet" href="../../styles/theme_style.css">
# <!--link rel="stylesheet" href="../../styles/header_style.css"-->
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
#
# <table width="100%">
#     <tr>
#         <td id="image_td" width="15%" class="header_image_color_4"><div id="image_img" class="header_image_4"></div></td>
#         <td class="header_text">How to install biosignalsnotebooks PyPI package? </td>
#     </tr>
# </table>

# %% [markdown]
# <div id="flex-container">
#     <div id="diff_level" class="flex-item">
#         <strong>Difficulty Level:</strong>   <span class="fa fa-star checked"></span>
#                                 <span class="fa fa-star"></span>
#                                 <span class="fa fa-star"></span>
#                                 <span class="fa fa-star"></span>
#                                 <span class="fa fa-star"></span>
#     </div>
#     <div id="tag" class="flex-item-tag">
#         <span id="tag_list">
#             <table id="tag_list_table">
#                 <tr>
#                     <td class="shield_left">Tags</td>
#                     <td class="shield_right" id="tags">Installation_Biosignalsnotebooks&#9729;PyPI&#9729;conversion</td>
#                 </tr>
#             </table>
#         </span>
#         <!-- [OR] Visit https://img.shields.io in order to create a tag badge-->
#     </div>
# </div>

# %% [markdown]
# For using <strong><span class="color2">BioSignalsnotebooks</span></strong> package, you need to follow any of two methods in below:

# %% [markdown]
# <p class="steps">1 - Installation of Biosignalsnotebooks package by using Promp command window "cmd"</p>

# %% [markdown]
# -Open the  window command prompt(console)

# %%
# Embedding of .jpg file
from IPython.display import Image
PATH = "../../images/other/"
Image(filename = PATH + "cmd.jpg", width=1000, height=500)

# %% [markdown]
# Open the Command window "pip install (package name)" by typing cmd at the start menu

# %%
# Embedding of .jpg file
from IPython.display import Image
PATH = "../../images/other/"
Image(filename = PATH + "Pip install.jpg", width=1000, height=500)

# %% [markdown]
# -Wait until the end of download/ installation

# %%
# Embedding of .jpg file
from IPython.display import Image
PATH = "../../images/other/"
Image(filename = PATH + "Finished_waiting.jpg", width=1000, height=500)

# %%
# Embedding of .jpg file
from IPython.display import Image
PATH = "../../images/other/"
Image(filename = PATH + "cmd.jpg", width=1000, height=500)

# %% [markdown]
# -Check if the package was correctly installed by trying to import it on python console

# %%
# Embedding of .jpg file
from IPython.display import Image
PATH ="../../images/other/"
Image(filename = PATH + "checking_python_for_package.jpg", width=1000, height=500)

# %% [markdown]
# <p class="steps">2 -Installation without pip</p>

# %% [markdown]
# -Download the unzipe the package to your local hard drive throgh the website "https://pypi.org"

# %% [markdown]
# -Search your the Project/Package ("Biosignalsnotebooks")

# %%
# Embedding of .jpg file
from IPython.display import Image
PATH = "../../images/other/"
Image(filename = PATH + "BIO.jpg", width=1000, height=500)

# %%
# Embedding of .jpg file
from IPython.display import Image
PATH = "../../images/other/"
Image(filename = PATH + "Bio1.jpg", width=1000, height=500)

# %%
# Embedding of .jpg file
from IPython.display import Image
PATH = "../../images/other/"
Image(filename = PATH + "Bio3.jpg", width=1000, height=500)

# %% [markdown]
# -Open a command prompt (e.g. Start–>cmd on Windows) and Navigate to the folder that contains the Biosignalsnotebooks.py file with the command cd <.tar.gz format>

# %%
# Embedding of .jpg file
from IPython.display import Image
PATH = "../../images/other/"
Image(filename = PATH + "cmd_part2.jpg", width=1000, height=500)

# %% [markdown]
# <strong><span class="color2">Similar Notebooks</span>, dedicated to the unit conversion of other sensors, are available in the following "conversion" section of <a href="../MainFiles/by_tag.ipynb">Notebooks Grouped by Tag page<img src="../../images/icons/link.png" width="10px" height="10px" style="display:inline"></a> </span></strong>

# %% [markdown]
# <span class="color6">**Auxiliary Code Segment (should not be replicated by the user)**</span>

# %%
from biosignalsnotebooks.__notebook_support__ import css_style_apply
css_style_apply()
# Out:
# .................... CSS Style Applied to Jupyter Notebook .........................
# <div id='style_import'><style>
# @import url(https://fonts.googleapis.com/css?family=Cuprum|Lato);
# body {
# font-family: 'Cuprum' !important;
# font-size: 12pt !important;
# line-height: 1 !important;
# font-weight: 400 !important;
# color: #58585A !important;
# text-align: justify !important;
# text-justify: inter-word !important;
# background-color: white !important;
# }
# /*
# #notebook-container {
# -webkit-box-shadow: none;
# box-shadow: none;
# }
# .rendered_html h1 { font-size: 4rem !important;  }
# .rendered_html h2 { font-size: 3rem !important; }
# .rendered_html h3 { font-size: 2.5rem !important; }
# .rendered_html h4 { font-size: 2rem !important; }
# .rendered_html h5 { font-size: 1.5rem !important; }
# .rendered_html h6 { font-size: 1.5rem !important; }
# .rendered_html h1,
# .rendered_html h2,
# .rendered_html h3,
# .rendered_html h4,
# .rendered_html h5,
# .rendered_html h6 {
# ...

# %%
# %%html
# <script>
#     // AUTORUN ALL CELLS ON NOTEBOOK-LOAD!
#     require(
#         ['base/js/namespace', 'jquery'],
#         function(jupyter, $) {
#             $(jupyter.events).on("kernel_ready.Kernel", function () {
#                 console.log("Auto-running all cells-below...");
#                 jupyter.actions.call('jupyter-notebook:run-all-cells-below');
#                 jupyter.actions.call('jupyter-notebook:save-notebook');
#             });
#         }
#     );
# </script>
# Out:
# <script>
#     // AUTORUN ALL CELLS ON NOTEBOOK-LOAD!
#     require(
#         ['base/js/namespace', 'jquery'],
#         function(jupyter, $) {
#             $(jupyter.events).on("kernel_ready.Kernel", function () {
#                 console.log("Auto-running all cells-below...");
#                 jupyter.actions.call('jupyter-notebook:run-all-cells-below');
#                 jupyter.actions.call('jupyter-notebook:save-notebook');
#             });
#         }
#     );
# </script>
